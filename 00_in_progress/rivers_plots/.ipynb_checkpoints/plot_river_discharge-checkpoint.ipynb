# %%
# Plot river discharge USGS data

### gen_fluxth_USGS.py --> m^3/second

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

path = 'usgs/Neuse_02091814_2017_2019_15min.txt' # Neuse
path2 = 'usgs/Tar_02084000_2017_2019_15min.txt' # Tar-Pamlico

path3 = 'usgs/Pasquotank_0204382800_2017_2019_15min.txt' # Pasquotank
path4 = 'usgs/Roanoke_02080500_2017_2019_15min.txt' # Roanoke

df = pd.read_csv(path, sep='\t', skiprows=24)
df2 = pd.read_csv(path2, sep='\t', skiprows=25)
df3 = pd.read_csv(path3, sep='\t', skiprows=24)
df4 = pd.read_csv(path4, sep='\t', skiprows=24)

df = df.drop(index=0)
df2 = df2.drop(index=0)
df3 = df3.drop(index=0)
df4 = df4.drop(index=0)

#print(df)
#print(df2)
#print(df4)

# %%
# make a timeseries of Discharge for (1) Neuse and Pamlico and (2) Chowan and Roanoke (???)

tN = np.asarray(pd.to_datetime(df.iloc[:, 2]))
dN = np.asarray(df.iloc[:, 4]) 

tT = np.asarray(pd.to_datetime(df2.iloc[:, 2]))
dT = np.asarray(df2.iloc[:, 4]) 

tP = np.asarray(pd.to_datetime(df3.iloc[:, 2]))
dP = np.asarray(df2.iloc[:, 4]) 

tR = np.asarray(pd.to_datetime(df4.iloc[:, 2]))
dR = np.asarray(df2.iloc[:, 4]) 


start_date = pd.to_datetime('2019-01-01')
index = np.where(tN == start_date)[0]
start = index[0]

if index.size > 0:
    print(f"Index of datetime 1/1/2019: {index[0]}")
else:
    print("Datetime 1/1/2019 not found in the array.")

end = len(tN)
tN = tN[start:end]
dN = dN[start:end]

tT = tT[start:end]
dT = dT[start:end]

tP = tP[start:end]
dP = dP[start:end]

tR = tR[start:end]
dR = dR[start:end]

#min_dN = int(np.min(dN))
#max_dN = int(np.max(dN))
#print(min(dN), max_dN)
# Out:
# Index of datetime 1/1/2019: 33481

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 5))
ax[0].plot(tN, np.asarray(dN,float),marker='.')
ax[0].tick_params(axis='x')
ax[0].set_ylabel('Discharge Rate (m/s)')
ax[0].plot(tT, np.asarray(dT,float),marker='o')


ax[1].plot(tP, np.asarray(dP,float),marker='.')
ax[1].tick_params(axis='x')
ax[1].set_ylabel('Discharge Rate (m/s)')
ax[1].plot(tR, np.asarray(dR,float),marker='o')
ax[1].set_xlabel('Time')


'''
plt.figure(figsize=(10, 5))
plt.plot(t, d, marker='o', linestyle='-')
plt.xlabel('Time')
plt.ylabel('River Discharge (cfs)')
plt.title('Neuse River Discharge 2018 - 2019')
plt.xticks(rotation=45)  
plt.set_ylabel('Floats')

plt.savefig('discharge_plots_2019.png', format='png')
'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/x9/p_chwt0x52dgywjzc864nsd40000gn/T/ipykernel_85332/2957917773.py in <module>
#       6
#       7
# ----> 8 ax[1].plot(tP, np.asarray(dP,float),marker='.')
#       9 ax[1].tick_params(axis='x')
#      10 ax[1].set_ylabel('Discharge Rate (m/s)')
#
# /opt/homebrew/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# /opt/homebrew/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# /opt/homebrew/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     496
#     497         if x.shape[0] != y.shape[0]:
# --> 498             raise ValueError(f"x and y must have same first dimension, but "
#     499                              f"have shapes {x.shape} and {y.shape}")
#     500         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (26680,) and (33568,)
